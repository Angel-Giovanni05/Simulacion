# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel-Giovanni05/Simulacion/blob/main/Unidad%203/Distribucion_Binomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simulacion
# ##Unidad 3
# Alumno:Angel GIovanni Romero Salazar
#
#
# #Problema 1: Distribución Binomial
# Contexto: Un distribuidor de artículos electrónicos recibe varios pedidos
# diarios. Cada día, el distribuidor tiene una probabilidad de éxito de cumplir
# un pedido (es decir, de tener en stock los artículos solicitados) del 70%.
# Desea simular la cantidad de pedidos diarios que logra satisfacer para
# gestionar adecuadamente sus inventarios y minimizar las faltantes de
# stock.
# ##Objetivo: Generar una variable aleatoria que simule el número de pedidos
# satisfechos por día durante una semana, considerando que cada día el
# distribuidor recibe 20 pedidos.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros de la distribución binomial
n_pedidos = 20  # Número de pedidos por día
p_exito = 0.7  # Probabilidad de satisfacer un pedido
dias = 7  # Número de días en la simulación

# Simulación de la cantidad de pedidos satisfechos por día
pedidos_satisfechos = np.random.binomial(n_pedidos, p_exito, dias)

# Mostrar los resultados
print("Pedidos satisfechos por día en una semana:", pedidos_satisfechos)

# Visualización de los datos
plt.figure(figsize=(8,5))
plt.bar(range(1, dias+1), pedidos_satisfechos, color='skyblue', edgecolor='black')
plt.xlabel("Día")
plt.ylabel("Pedidos Satisfechos")
plt.title("Simulación de Pedidos Satisfechos en una Semana")
plt.xticks(range(1, dias+1))
plt.ylim(0, n_pedidos)
plt.show()
# Out:
# Pedidos satisfechos por día en una semana: [17  9 18 13 14 15 15]
